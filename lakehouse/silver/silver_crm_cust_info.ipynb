# %% [markdown]
# # Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType
from pyspark.sql.functions import trim, col

# %% [markdown]
# # Reading from Bronze Table

# %%
df = spark.table("workspace.bronze.crm_cust_info")

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Drop Duplicates

# %%
df = df.dropDuplicates()

# %% [markdown]
# ## Trimming

# %%
for field in df.schema.fields:
  if isinstance(field.dataType, StringType):
    df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ## Normalization

# %%
df = (
    df
    .withColumn(
        "cst_marital_status",
        F.when(F.upper(F.col("cst_marital_status")) == "M", "Married")
        .when(F.upper(F.col("cst_marital_status")) == "S", "Single")
        .otherwise("n/a")
    )

    .withColumn(
        "cst_gndr",
        F.when(F.upper(F.col("cst_gndr")) == "M", "Male")
        .when(F.upper(F.col("cst_gndr")) == "F", "Female")
        .otherwise("n/a")
    )
        
)

# %% [markdown]
# ## Remove Missing Cust ID

# %%
df = df.filter(col("cst_id").isNotNull())

# %% [markdown]
# ## Rename Column

# %%
RENAME_MAP = {
    "cst_id": "customer_id",
    "cst_key": "customer_key",
    "cst_firstname": "first_name",
    "cst_lastname": "last_name",
    "cst_marital_status": "marital_status",
    "cst_gndr": "gender",
    "cst_create_date": "created_date"
}

for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name,new_name)

# %% [markdown]
# # Writing to Silver Table

# %%
(
    df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("silver.crm_cust_info")
)

# %% [markdown]
# ## Sanity checks of Bronze Table

# %%
# %sql
select * from workspace.silver.crm_cust_info limit 10
